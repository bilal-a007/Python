# %% [markdown]
# <a href="https://colab.research.google.com/github/bilal-a007/Python/blob/main/Toshakhana%20analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import math as m

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6827bb0d-c7bd-414a-808b-e7a50a5e2b10" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6827bb0d-c7bd-414a-808b-e7a50a5e2b10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Refined_TK_data ver 2.csv')

# %%
df.head()
# Out:
#                      Detail of Gifts      Item Category  \
# 0          Two  small  silver\nBowls  Decoration Pieces
# 1            One Pilot Pen with\nink                Pen
# 2                    One silver vase  Decoration Pieces
# 3  One  (decoration)\nfolding Screen  Decoration Pieces
# 4             One  Decoration\nPiece  Decoration Pieces
#
#                                    Name of Recipient          Affiliation  \
# 0  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...  Gen. Musharrafarraf
# 1  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...       Gen. Musharraf
# 2             Mr. Shaukat Aziz, Minister for Finance       Gen. Musharraf
# 3  Mr.  Abdul Sattar,  Minister  for  Foreign\nAf...       Gen. Musharraf
# 4  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...       Gen. Musharraf
#
#         Date  Assessed Value  Retention Cost Retained Remarks
# 0   1/8/2002          5000.0             0.0      Yes     Yes
# ...

# %%
df.dtypes
# Out:
# Detail of Gifts       object
# Item Category         object
# Name of Recipient     object
# Affiliation           object
# Date                  object
# Assessed Value       float64
# Retention Cost       float64
# Retained              object
# Remarks               object
# dtype: object

# %%
# 0,1,2,3 ... are index
# object means text/string,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4214 entries, 0 to 4213
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Detail of Gifts    4208 non-null   object
#  1   Item Category      2338 non-null   object
#  2   Name of Recipient  4214 non-null   object
#  3   Affiliation        3207 non-null   object
#  4   Date               4211 non-null   object
#  5   Assessed Value     4213 non-null   float64
#  6   Retention Cost     4205 non-null   float64
#  7   Retained           4203 non-null   object
#  8   Remarks            4203 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 296.4+ KB

# %%
df.shape
# Out:
# (4214, 9)

# %%
df.describe()
# Out:
#        Assessed Value  Retention Cost
# count    4.213000e+03    4.205000e+03
# mean     3.210531e+05    4.851276e+04
# std      3.894070e+06    6.184538e+05
# min      0.000000e+00    0.000000e+00
# 25%      1.700000e+03    0.000000e+00
# 50%      8.000000e+03    0.000000e+00
# 75%      4.000000e+04    2.250000e+03
# max      1.400000e+08    2.017800e+07

# %%
#50% is median
df.describe(include ='O')
# Out:
#        Detail of Gifts Item Category  \
# count             4208          2338
# unique            3248            22
# top         One Carpet         Watch
# freq                53          1102
#
#                                        Name of Recipient Affiliation  \
# count                                               4214        3207
# unique                                              2047          12
# top     Mr.  Shaukat  Aziz,  Prime\nMinister of Pakistan    Military
# freq                                                 698         734
#
#              Date Retained Remarks
# count        4211     4203    4203
# unique       1450       72     229
# top     7/22/2010      Yes     Yes
# freq           47     3730    3730

# %%
#top means most occurances e.g. Mr. Shaukat Aziz, Prime\nMinister of Pakistan	ne sb se zyada lia, military ne sb se zyada lia in affiliation
# freq means count of watch etc.

# %%
df['Detail of Gifts'].value_counts()
# Out:
# Detail of Gifts
# One Carpet                                                                                    53
# One carpet                                                                                    38
# One shield                                                                                    32
# One  Packet  Containing\nPair  of  Cufflinks,  Pen  &\nWallet                                 26
# Wrist  Watch\n(Concord)                                                                       20
#                                                                                               ..
# Emblem  of  15th Asia\nGames (Doha)\nORRY  Official  Mascot\nof  15th Asia  Games\n(Doha)      1
# Emblem  of  African\nUnion African Day                                                         1
# One  Scenery  of\nAzerbaijan                                                                   1
# ...

# %%
df['Detail of Gifts'].value_counts().values
# Out:
# array([53, 38, 32, ...,  1,  1,  1])

# %%
df[df['Detail of Gifts'].isin(['One Carpet', 'One carpet'])]['Detail of Gifts'].value_counts()
# Out:
# Detail of Gifts
# One Carpet    53
# One carpet    38
# Name: count, dtype: int64

# %%
#Lambda function
df['Detail of Gifts'] = df['Detail of Gifts'].apply(lambda x: lower(x))
#then run this code

# %%
def lower(x):
    try:
        return x.lower()  # Call the lower() method on the string
    except: # Catch only the specific error if x is not a string
        return x
#first run this code

# %%
#shallow main 2 jagagh copy hota ha
#deep copy
# Out:
# Series([], Name: count, dtype: int64)

# %%
df['Detail of Gifts'].value_counts()
# Out:
# Detail of Gifts
# one carpet                                                                                                                                         91
# one flower vase                                                                                                                                    37
# one shield                                                                                                                                         33
# one  packet  containing\npair  of  cufflinks,  pen  &\nwallet                                                                                      27
# one decoration piece                                                                                                                               26
#                                                                                                                                                    ..
# ...

# %%
df['Name of Recipient'].value_counts()
# Out:
# Name of Recipient
# Mr.  Shaukat  Aziz,  Prime\nMinister of Pakistan                                698
# Mr.  Asif  Ali  Zardari,\nPresident of Pakistan                                 131
# Mr.  Khurshid  M.  Kasuri,\nForeign Minister                                     66
# Mr.  Imran  Khan,\nPrime  Minister  of\nPakistan                                 49
# Mian  Muhammad  Shehbaz  Sharif,\nPrime Minister of Pakistan                     48
#                                                                                ...
# Hav.  Walayat  Shah,\nSecurity Official                                           1
# Sub.  Muhammad  Saleem,\nSecurity Officer,                                        1
# Mr.  Muhammad  Uzair\nShafiq, Protocol Assistant                                  1
# Mr.  Fayyaz  Muhammad,\nProtocol  Assistant  to\nPresident                        1
# SP  Mahzoor  Ali Ghauri,  Chief\nSecurity  Officer  to  the  Prime\nMinister      1
# ...

# %%
df['Name'] = df['Name of Recipient'].apply (lambda x: x.split (',') [0])

# %%
df['Name'] . value_counts()
# Out:
# Name
# Mr.  Shaukat  Aziz               775
# Mr.  Asif  Ali  Zardari          167
# Mr.  Khurshid  M.  Kasuri        103
# Mr.  Imran  Khan                  83
# Mir  Zafarullah  Khan\nJamali     75
#                                 ...
# Mrs.  Adnan  A.\nKhawaja           1
# Mr.  Adnan  A.\nKhawaja            1
# Mr  Ghalib  Iqbal                  1
# Mr.  Muhammad\nJunaid  Khan        1
# SP  Mahzoor  Ali Ghauri            1
# Name: count, Length: 1607, dtype: int64

# %%
#Retain = Yes
#df[df['Retained'].isin('Yes')] ['Name'].value_counts()
df[df['Retained'].isin(['Yes'])]['Name'].value_counts()

#df[df['Detail of Gifts'].isin(['One Carpet', 'One carpet'])]['Detail of Gifts'].value_counts()
# Out:
# Name
# Mr.  Shaukat  Aziz                                       750
# Mr.  Asif  Ali  Zardari                                  166
# Mr.  Khurshid  M.  Kasuri                                 98
# Mir  Zafarullah  Khan\nJamali                             71
# Dr.  Arif  Alvi                                           50
#                                                         ...
# Mr.  Khalid  Aziz  Babar                                   1
# Capt.  Tahira  Mubarik                                     1
# Sqn  Ldr  Shahzad  Fatah                                   1
# Mr.  Faisal Nisar  Liaison\nOfficer to Prime Minister      1
# SP  Mahzoor  Ali Ghauri                                    1
# Name: count, Length: 1434, dtype: int64

# %%
#df[df['Retained'].isin(['Yes']) df['Name'].isin(['Imran'])]['Name'].value_counts()

df[df['Retained'].isin(['Yes']) & df['Name'].isin(['Dr. Arif Alvi'])]['Name'].value_counts()
# Out:
# Name
# Dr. Arif Alvi    44
# Name: count, dtype: int64

# %%
df[df['Retained'].isin(['Yes']) & (df['Assessed Value'] > 100000)].sort_values(by=['Assessed Value'])
# Out:
#                                         Detail of Gifts      Item Category  \
# 191         one  table  clock\nwith  replica  of\nhorse  Decoration Pieces
# 187   one wrist watch\n(audmars\npiguet)  with  pair...              Watch
# 3359  (a)iphone  6  plus  128\ngb.\n(b)one  w/watch\...              Watch
# 1494  one  leather  hand  bag\ncontaining: -\na. one...                NaN
# 3989  a. one shield\nb. one  zafer  migfer/\nmirror\...                NaN
# ...                                                 ...                ...
# 3496  a) one  w/watch\n(faberge  tof14-\nlimited  ed...              Watch
# 3249  (a)one bracelet.\n(b)one  necklace  &  ear\nring.                NaN
# 3463  one  jewelry  set\nincluding one necklace,\na ...                NaN
# 3600  a) (one  w/watch  (graff\nno.au750)  18k  gold...              Watch
# 2207  a. one  bmw  760  li\n(security  version)\n(mo...                NaN
#
# ...

# %%
df.groupby(by =['Name']) ['Assessed Value'].sum()
# Out:
# Name
#   Mian  Muhammad\nShehbaz  Sharif          0.0
#   Mr. Ghous Bux Khan\nMahar            76800.0
#   PA-33733 Lt Col Abid                 23000.0
# (a)  Prime  Minister                       0.0
# (a) Mr.  Muhammad\nNawaz  Sharif       10000.0
#                                        ...
# Wing  Commander\nWaqar  Ahmad           1500.0
# Wing  Commander  Waqar\nAhmad           3500.0
# Zafarullah  khan\nJamali               50000.0
# Zeeshan  Ahmed                       1010000.0
# a)  Dr.  Arif  Alvi                      800.0
# Name: Assessed Value, Length: 1607, dtype: float64

# %%
#find Affiliation
df[(df['Retained']=='Yes') & (df['Name']=='Mr. Shaukat Aziz')]['Name'].value_counts()

df_filtered_sorted = df[(df['Retained'] == 'Yes') & (df['Assessed Value'] > 1000000)].sort_values('Assessed Value', ascending=False)

df_retained = df[df['Retained']=='Yes']

df_retained.groupby(by=['Name of Recipient', 'Item Category']) ['Assessed Value'].sum().reset_index().sort_values(by=['Assessed Value'],ascending=False).head(10)
# Out:
#                                       Name of Recipient Item Category  \
# 1339        Prime  Minister  of\nPakistan,  Imran\nKhan         Watch
# 1203  Mr. Muhammad  Nawaz\nSharif,  Prime  Minister\...         Watch
# 381           Khawaja  Muhammad\nAsif, Foreign Minister         Watch
# 1233  Mr. Shahid Khaqan\nAbbasi,  Prime\nMinister  o...         Watch
# 1347  Prime  Minister  of\nPakistan,  Mr.  Shahid\nK...         Watch
# 1338  Prime  Minister  of\nPakistan,\nMr.  Shahid  K...         Watch
# 622                      Mr.  Abdullah  Khaqan\nAbbasi.         Watch
# 977   Mr.  Nadir  Khaqan\nAbbasi,  son  of\nPrime Mi...         Watch
# 1100   Mr.  Shaukat  Aziz,  Prime\nMinister of Pakistan         Watch
# 255                                       Dr. Abid Riaz         Watch
#
#       Assessed Value
# 1339     104720000.0
# 1203      61098779.0
# 381       56218788.0
# 1233      26425000.0
# 1347      23000000.0
# 1338      22550000.0
# 622       21346000.0
# ...

# %%
df_retained.groupby(by=['Affiliation']) ['Assessed Value'].sum().reset_index().sort_values(by=['Assessed Value'],ascending=False).head(10)
# Out:
#        Affiliation  Assessed Value
# 8             PMLN     258114029.0
# 9              PPP     156152678.0
# 10             PTI     137060556.0
# 7         Military      76054823.0
# 0      Bureaucracy      32371772.0
# 1          Gen Mus      21425871.0
# 11          Police      15415700.0
# 2   Gen. Musharraf      13745382.0
# 6            Media       6257900.0
# 4        Judiciary        850200.0

# %%
df.head()
# Out:
#                      Detail of Gifts      Item Category  \
# 0          two  small  silver\nbowls  Decoration Pieces
# 1            one pilot pen with\nink                Pen
# 2                    one silver vase  Decoration Pieces
# 3  one  (decoration)\nfolding screen  Decoration Pieces
# 4             one  decoration\npiece  Decoration Pieces
#
#                                    Name of Recipient          Affiliation  \
# 0  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...  Gen. Musharrafarraf
# 1  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...       Gen. Musharraf
# 2             Mr. Shaukat Aziz, Minister for Finance       Gen. Musharraf
# 3  Mr.  Abdul Sattar,  Minister  for  Foreign\nAf...       Gen. Musharraf
# 4  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...       Gen. Musharraf
#
#         Date  Assessed Value  Retention Cost Retained Remarks  \
# 0   1/8/2002          5000.0             0.0      Yes     Yes
# ...

# %%
#df[df['Name of Recipient'].str.contains(['Wife'])]
#.groupby(by=['Affiliation']) ['Assessed Value'].sum().reset_index().sort_values(by=['Assessed Value'],ascending=False).head(10)
df[df['Name of Recipient'].str.contains('Wife', case=False, na=False)].groupby(by=['Name of Recipient']) ['Assessed Value'].count().reset_index().sort_values(by=['Assessed Value'],ascending=False).head(10)
# Out:
#                                     Name of Recipient  Assessed Value
# 14  Begum  Sahiba,  Wife  of\nMr.  Shaukat  Aziz, ...              17
# 50  The  first  lady  of\nPakistan,  wife  of  Dr....              10
# 26  First  Lady  of\nPakistan,  wife  of  Mr.\nMam...               4
# 60               Wife  of  Mr.  Shahid\nKhaqan Abbasi               3
# 15  Begum  Sahiba,  wife  of\nMr.  Shaukat  Aziz, ...               3
# 19  Begum Prime Minister of\nPakistan,  Wife  of  ...               2
# 43   Mrs.  Shaukat  Aziz  wife  of  Finance\nMinister               2
# 33  First  lady of Pakistan,\nwife  of  Mr.  Mamno...               2
# 30  First  Lady  of  Pakistan,  wife\nof  Presiden...               2
# 29  First  Lady  of  Pakistan,\nwife  of\nMr.  Mam...               2

# %%
df_retained.head()
# Out:
#                      Detail of Gifts      Item Category  \
# 0          two  small  silver\nbowls  Decoration Pieces
# 1            one pilot pen with\nink                Pen
# 2                    one silver vase  Decoration Pieces
# 3  one  (decoration)\nfolding screen  Decoration Pieces
# 4             one  decoration\npiece  Decoration Pieces
#
#                                    Name of Recipient          Affiliation  \
# 0  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...  Gen. Musharrafarraf
# 1  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...       Gen. Musharraf
# 2             Mr. Shaukat Aziz, Minister for Finance       Gen. Musharraf
# 3  Mr.  Abdul Sattar,  Minister  for  Foreign\nAf...       Gen. Musharraf
# 4  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...       Gen. Musharraf
#
#         Date  Assessed Value  Retention Cost Retained Remarks  \
# 0   1/8/2002          5000.0             0.0      Yes     Yes
# ...

# %%
df['DIfference'] = df['Assessed Value']- df['Retention Cost']
df['DIfference']
# Out:
# 0         5000.0
# 1         3500.0
# 2         7500.0
# 3         2200.0
# 4         2000.0
#           ...
# 4209     35000.0
# 4210     36000.0
# 4211     85000.0
# 4212     50000.0
# 4213    434000.0
# Name: DIfference, Length: 4214, dtype: float64

# %%
#df_retained.head().sort_values(by=df_retained['a'], ascending=False)

df.sort_values(by=['DIfference'], ascending=False)
# Out:
#                                         Detail of Gifts      Item Category  \
# 4114  one wrist watch rolex\n(model\nno.326259tbr-sr...              Watch
# 2207  a. one  bmw  760  li\n(security  version)\n(mo...                NaN
# 3600  a) (one  w/watch  (graff\nno.au750)  18k  gold...              Watch
# 3463  one  jewelry  set\nincluding one necklace,\na ...                NaN
# 3249  (a)one bracelet.\n(b)one  necklace  &  ear\nring.                NaN
# ...                                                 ...                ...
# 3323         one decoration piece\n(wooden flower vase)  Decoration Pieces
# 3616  one  w/watch  (rolex)\nsr.no.n76p9648-750  mod...              Watch
# 3627                           one wall hanging scenery                NaN
# 3820              one proton car\n(x70  proton  vehicle                NaN
# 4046  (serbiti) \n(j)two\nrahatlandyryjuy  (tea\nbag...               Food
#
# ...
