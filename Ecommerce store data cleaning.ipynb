# %%
import pandas as pd

# %% [markdown]
# ## Data Extraction # :

# %%
df = pd.read_csv('/content/Refined_TK_data ver 2.csv')

# %%
df.dtypes
# Out:
# Detail of Gifts       object
# Item Category         object
# Name of Recipient     object
# Affiliation           object
# Date                  object
# Assessed Value       float64
# Retention Cost       float64
# Retained              object
# Remarks               object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4214 entries, 0 to 4213
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Detail of Gifts    4208 non-null   object
#  1   Item Category      2338 non-null   object
#  2   Name of Recipient  4214 non-null   object
#  3   Affiliation        3207 non-null   object
#  4   Date               4211 non-null   object
#  5   Assessed Value     4213 non-null   float64
#  6   Retention Cost     4205 non-null   float64
#  7   Retained           4203 non-null   object
#  8   Remarks            4203 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 296.4+ KB

# %%
df.describe()
# Out:
#        Assessed Value  Retention Cost
# count    4.213000e+03    4.205000e+03
# mean     3.210531e+05    4.851276e+04
# std      3.894070e+06    6.184538e+05
# min      0.000000e+00    0.000000e+00
# 25%      1.700000e+03    0.000000e+00
# 50%      8.000000e+03    0.000000e+00
# 75%      4.000000e+04    2.250000e+03
# max      1.400000e+08    2.017800e+07

# %%
df.describe(include='O')
# Out:
#        Detail of Gifts Item Category  \
# count             4208          2338
# unique            3248            22
# top         One Carpet         Watch
# freq                53          1102
#
#                                        Name of Recipient Affiliation  \
# count                                               4214        3207
# unique                                              2047          12
# top     Mr.  Shaukat  Aziz,  Prime\nMinister of Pakistan    Military
# freq                                                 698         734
#
#              Date Retained Remarks
# count        4211     4203    4203
# unique       1450       72     229
# top     7/22/2010      Yes     Yes
# freq           47     3730    3730

# %%
df.head(2)
# Out:
#              Detail of Gifts      Item Category  \
# 0  Two  small  silver\nBowls  Decoration Pieces
# 1    One Pilot Pen with\nink                Pen
#
#                                    Name of Recipient          Affiliation  \
# 0  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...  Gen. Musharrafarraf
# 1  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...       Gen. Musharraf
#
#        Date  Assessed Value  Retention Cost Retained Remarks
# 0  1/8/2002          5000.0             0.0      Yes     Yes
# 1  1/8/2002          3500.0             0.0      Yes     Yes

# %% [markdown]
# ## Filter:

# %%
df['Detail of Gifts'].value_counts()
# Out:
# Detail of Gifts
# One Carpet                                                                                    53
# One carpet                                                                                    38
# One shield                                                                                    32
# One  Packet  Containing\nPair  of  Cufflinks,  Pen  &\nWallet                                 26
# Wrist  Watch\n(Concord)                                                                       20
#                                                                                               ..
# Emblem  of  15th Asia\nGames (Doha)\nORRY  Official  Mascot\nof  15th Asia  Games\n(Doha)      1
# Emblem  of  African\nUnion African Day                                                         1
# One  Scenery  of\nAzerbaijan                                                                   1
# ...

# %%
df[df['Detail of Gifts'].isin(['One Carpet','One carpet'])]['Detail of Gifts'].value_counts()
# Out:
# Detail of Gifts
# One Carpet    53
# One carpet    38
# Name: count, dtype: int64

# %%
df['Detail of Gifts'] = df['Detail of Gifts'].apply(lambda x: lower(x))

# %%
df['Detail of Gifts'].value_counts()
# Out:
# Detail of Gifts
# one carpet                                                                                                                                         91
# one flower vase                                                                                                                                    37
# one shield                                                                                                                                         33
# one  packet  containing\npair  of  cufflinks,  pen  &\nwallet                                                                                      27
# one decoration piece                                                                                                                               26
#                                                                                                                                                    ..
# ...

# %%
def lower(x):
  try:
    return str.lower(x)
  except:
    return x

# %%
df.columns.tolist()
# Out:
# ['Detail of Gifts',
#  'Item Category',
#  'Name of Recipient',
#  'Affiliation',
#  'Date',
#  'Assessed Value',
#  'Retention Cost',
#  'Retained',
#  'Remarks']

# %%
df['Name of Recipient'].tolist()
# Out:
# ['Mr.  Abdul  Sattar,  Minister  for  Foreign\nAffairs',
#  'Mr.  Abdul  Sattar,  Minister  for  Foreign\nAffairs',
#  'Mr. Shaukat Aziz, Minister for Finance',
#  'Mr.  Abdul Sattar,  Minister  for  Foreign\nAffairs',
#  'Mr.  Abdul  Sattar,  Minister  for  Foreign\nAffairs',
#  'Mr.  Ahmed  Waqar,  Secretary\nPrivatization Commission',
#  'Mr.  Abdul  Sattar,  Minister  for  Foreign\nAffairs',
#  'Mr. Shaukat Aziz, Minister for Finance',
#  'Dr.  Tariq  Hassan,  Advisor  to  Finance\nMinister',
#  'Mr.  Altaf  M.  Saleem,  Minster  for\nPrivatization',
#  'Mr.  Abdul  Sattar,  Minister  for  Foreign\nAffairs',
#  'Mr.  Abdul  Sattar,  Minister  for  Foreign\nAffairs',
#  'Dr.  Atta-ur- Rehman,  Minister  for\nScience & Technology',
#  'Dr.  Atta-ur- Rehman,  Minister  for\nScience & Technology',
#  'Dr.  Atta-ur- Rehman,  Minister  for\nScience & Technology',
#  'Dr.  Atta-ur- Rehman,  Minister  for\nScience & Technology',
# ...

# %%
df['Name'] =  df['Name of Recipient'].apply(lambda x: x.split(',')[0]).tolist()
#df['Designation'] =  df['Name of Recipient'].apply(lambda x: x.split(',')[1]).tolist()

# %%
df['Name'].value_counts()
# Out:
# Name
# Mr.  Shaukat  Aziz               775
# Mr.  Asif  Ali  Zardari          167
# Mr.  Khurshid  M.  Kasuri        103
# Mr.  Imran  Khan                  83
# Mir  Zafarullah  Khan\nJamali     75
#                                 ...
# Mrs.  Adnan  A.\nKhawaja           1
# Mr.  Adnan  A.\nKhawaja            1
# Mr  Ghalib  Iqbal                  1
# Mr.  Muhammad\nJunaid  Khan        1
# SP  Mahzoor  Ali Ghauri            1
# Name: count, Length: 1607, dtype: int64

# %%
df.head(2)
# Out:
#              Detail of Gifts      Item Category  \
# 0  two  small  silver\nbowls  Decoration Pieces
# 1    one pilot pen with\nink                Pen
#
#                                    Name of Recipient          Affiliation  \
# 0  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...  Gen. Musharrafarraf
# 1  Mr.  Abdul  Sattar,  Minister  for  Foreign\nA...       Gen. Musharraf
#
#        Date  Assessed Value  Retention Cost Retained Remarks  \
# 0  1/8/2002          5000.0             0.0      Yes     Yes
# 1  1/8/2002          3500.0             0.0      Yes     Yes
#
#                  Name
# 0  Mr.  Abdul  Sattar
# 1  Mr.  Abdul  Sattar

# %%
df[(df['Retained']=='Yes') & (df['Assessed Value']>1000000)].sort_values(by=['Assessed Value'],ascending=False)
# Out:
#                                         Detail of Gifts Item Category  \
# 2207  a. one  bmw  760  li\n(security  version)\n(mo...           NaN
# 3600  a) (one  w/watch  (graff\nno.au750)  18k  gold...         Watch
# 3463  one  jewelry  set\nincluding one necklace,\na ...           NaN
# 3249  (a)one bracelet.\n(b)one  necklace  &  ear\nring.           NaN
# 3496  a) one  w/watch\n(faberge  tof14-\nlimited  ed...         Watch
# ...                                                 ...           ...
# 3409    a) one  necklace\n(diamond)\nb) one table watch         Watch
# 3787  one  ladies  wrist  watch\nrolex  (m279173-001...         Watch
# 1600  a. one  table  clock\n“chelsea”\nb. one model ...         Watch
# 3603  a) one w/watch (chopard)\nb) pair of cufflinks...         Watch
# 3682                                one w/watch (rolex)         Watch
#
#                                       Name of Recipient Affiliation  \
# ...

# %%
df_retained = df[df['Retained']=='Yes']

# %%
df_retained.groupby(by=['Name of Recipient','Item Category'])
['Assessed Value'].sum().reset_index()
.sort_values(by=['Assessed Value'], ascending=False).head(10)
# Out:
#                                       Name of Recipient Item Category  \
# 1339        Prime  Minister  of\nPakistan,  Imran\nKhan         Watch
# 1203  Mr. Muhammad  Nawaz\nSharif,  Prime  Minister\...         Watch
# 381           Khawaja  Muhammad\nAsif, Foreign Minister         Watch
# 1233  Mr. Shahid Khaqan\nAbbasi,  Prime\nMinister  o...         Watch
# 1347  Prime  Minister  of\nPakistan,  Mr.  Shahid\nK...         Watch
# 1338  Prime  Minister  of\nPakistan,\nMr.  Shahid  K...         Watch
# 622                      Mr.  Abdullah  Khaqan\nAbbasi.         Watch
# 977   Mr.  Nadir  Khaqan\nAbbasi,  son  of\nPrime Mi...         Watch
# 1100   Mr.  Shaukat  Aziz,  Prime\nMinister of Pakistan         Watch
# 255                                       Dr. Abid Riaz         Watch
#
#       Assessed Value
# 1339     104720000.0
# 1203      61098779.0
# 381       56218788.0
# 1233      26425000.0
# 1347      23000000.0
# 1338      22550000.0
# 622       21346000.0
# ...

# %%
df['Item Category'].value_counts()
# Out:
# Item Category
# Watch                         1102
# Decoration Pieces              553
# Carpet                         243
# Pen                            119
# Crockery                       108
# Jewellery/Accessories           50
# Phone                           34
# Cigar/Cigarettes                34
# Weapons                         27
# Clothes                         26
# Food                            12
# Bags                            12
# Tech                             8
# Watch, Weapons                   2
# Watch, phone                     1
# Technology                       1
# Watch, Tech                      1
# Clock                            1
# Jewellery, Weapons               1
# Bag, Jewellery/Accessories       1
# Pen, Jewelry                     1
# Tech, pen                        1
# Name: count, dtype: int64

# %%
def check_gift(x):
  try:
    if 'bmw' in x:
      return 'car'
    else:
      return 'no car'
  except:
    return x

# %%
df['flag'] = df['Detail of Gifts'].apply(lambda x: check_gift(x))

# %%
df[df['flag']=='car']
# Out:
#                                         Detail of Gifts Item Category  \
# 2207  a. one  bmw  760  li\n(security  version)\n(mo...           NaN
# 2208  one  bmw  760  li\nwhite  (security\nversion) ...           NaN
#
#                                       Name of Recipient Affiliation  \
# 2207  Mr.  Asif  Ali  Zardari,\nPresident  of\nPakistan         PPP
# 2208   Mr  Asif  Ali  Zardari,\nPresident  of\nPakistan         PPP
#
#            Date  Assessed Value  Retention Cost Retained Remarks  \
# 2207  1/26/2009     107828705.0      16172806.0      Yes     Yes
# 2208  1/26/2009      27339370.0       4099406.0      Yes     Yes
#
#                          Name flag
# 2207  Mr.  Asif  Ali  Zardari  car
# 2208   Mr  Asif  Ali  Zardari  car

# %%
def check(x):
  try:
    if 'wife' in x:
      return 'family'
    else:
      return 'others'
  except:
    return 'others'

# %%
df['Name of Recipient'] = df['Name of Recipient'].apply(lambda x: lower(x))

# %%
df['family'] = df['Name of Recipient'].apply(lambda x: check(x))

# %%
df[df['family']=='family']['Name of Recipient'].value_counts()
# Out:
# Name of Recipient
# begum  sahiba,  wife  of\nmr.  shaukat  aziz,  prime\nminister of pakistan                                                                          21
# the  first  lady  of\npakistan,  wife  of  dr.  arif\nalvi                                                                                          10
# first  lady  of\npakistan,  wife  of  mr.\nmamnoon hussain                                                                                           4
# wife  of  mr.  shahid\nkhaqan abbasi                                                                                                                 3
# mrs.  shaukat  aziz  wife  of  finance\nminister                                                                                                     2
#                                                                                                                                                     ..
# ...

# %%
df['Name of Recipient'].tolist()
# Out:
# ['mr.  abdul  sattar,  minister  for  foreign\naffairs',
#  'mr.  abdul  sattar,  minister  for  foreign\naffairs',
#  'mr. shaukat aziz, minister for finance',
#  'mr.  abdul sattar,  minister  for  foreign\naffairs',
#  'mr.  abdul  sattar,  minister  for  foreign\naffairs',
#  'mr.  ahmed  waqar,  secretary\nprivatization commission',
#  'mr.  abdul  sattar,  minister  for  foreign\naffairs',
#  'mr. shaukat aziz, minister for finance',
#  'dr.  tariq  hassan,  advisor  to  finance\nminister',
#  'mr.  altaf  m.  saleem,  minster  for\nprivatization',
#  'mr.  abdul  sattar,  minister  for  foreign\naffairs',
#  'mr.  abdul  sattar,  minister  for  foreign\naffairs',
#  'dr.  atta-ur- rehman,  minister  for\nscience & technology',
#  'dr.  atta-ur- rehman,  minister  for\nscience & technology',
#  'dr.  atta-ur- rehman,  minister  for\nscience & technology',
#  'dr.  atta-ur- rehman,  minister  for\nscience & technology',
# ...

# %%
df.head(2)
# Out:
#              Detail of Gifts      Item Category  \
# 0  two  small  silver\nbowls  Decoration Pieces
# 1    one pilot pen with\nink                Pen
#
#                                    Name of Recipient          Affiliation  \
# 0  mr.  abdul  sattar,  minister  for  foreign\na...  Gen. Musharrafarraf
# 1  mr.  abdul  sattar,  minister  for  foreign\na...       Gen. Musharraf
#
#        Date  Assessed Value  Retention Cost Retained Remarks  \
# 0  1/8/2002          5000.0             0.0      Yes     Yes
# 1  1/8/2002          3500.0             0.0      Yes     Yes
#
#                  Name    flag  family
# 0  Mr.  Abdul  Sattar  no car  others
# 1  Mr.  Abdul  Sattar  no car  others

# %%
df['diff'] = df['Assessed Value'] - df['Retention Cost']

# %%
df.sort_values(by=['diff'],ascending=False)[['Detail of Gifts',	'Item Category','Name of Recipient','Affiliation','diff']]
# Out:
#                                         Detail of Gifts      Item Category  \
# 4114  one wrist watch rolex\n(model\nno.326259tbr-sr...              Watch
# 2207  a. one  bmw  760  li\n(security  version)\n(mo...                NaN
# 3600  a) (one  w/watch  (graff\nno.au750)  18k  gold...              Watch
# 3463  one  jewelry  set\nincluding one necklace,\na ...                NaN
# 3249  (a)one bracelet.\n(b)one  necklace  &  ear\nring.                NaN
# ...                                                 ...                ...
# 3323         one decoration piece\n(wooden flower vase)  Decoration Pieces
# 3616  one  w/watch  (rolex)\nsr.no.n76p9648-750  mod...              Watch
# 3627                           one wall hanging scenery                NaN
# 3820              one proton car\n(x70  proton  vehicle                NaN
# 4046  (serbiti) \n(j)two\nrahatlandyryjuy  (tea\nbag...               Food
#
# ...

# %%
import pandas as pd
from tqdm import tqdm
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv('/content/Pakistan Largest Ecommerce Dataset.csv')
# Out:
# <ipython-input-2-6f7364e66f38>:1: DtypeWarning: Columns (1,2,3,7,8,9,11,12,13,14,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Pakistan Largest Ecommerce Dataset.csv')

# %%
df.shape
# Out:
# (1048575, 26)

# %%
df.head()
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete   7/1/2016
# 1  211133.0        canceled   7/1/2016
# 2  211134.0        canceled   7/1/2016
# 3  211135.0        complete   7/1/2016
# 4  211136.0  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# ...

# %%
df[df['item_id'].notnull()]
# Out:
#          item_id          status created_at  \
# 0       211131.0        complete   7/1/2016
# 1       211133.0        canceled   7/1/2016
# 2       211134.0        canceled   7/1/2016
# 3       211135.0        complete   7/1/2016
# 4       211136.0  order_refunded   7/1/2016
# ...          ...             ...        ...
# 584519  905204.0             cod  8/28/2018
# 584520  905205.0      processing  8/28/2018
# 584521  905206.0      processing  8/28/2018
# 584522  905207.0      processing  8/28/2018
# 584523  905208.0      processing  8/28/2018
#
#                                                       sku     price  \
# 0                                       kreations_YI 06-L    1950.0
# 1       kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...     240.0
# 2                                      Ego_UP0017-999-MR0    2450.0
# 3                                          kcc_krone deal     360.0
# 4                                             BK7010400AG     555.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  float64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  float64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
#  9   sales_commission_code  447346 non-null  object
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  object
#  12  Working Date           584524 non-null  object
#  13  BI Status              584524 non-null  object
# ...

# %% [markdown]
# ## 01. Clean Data:

# %%
df = df[['item_id',
 'status',
 'created_at',
 'sku',
 'price',
 'qty_ordered',
 'grand_total',
 'increment_id',
 'category_name_1',
 'sales_commission_code',
 'discount_amount',
 'payment_method',
 'Working Date',
 'BI Status',
 ' MV ',
 'Year',
 'Month',
 'Customer Since',
 'M-Y',
 'FY',
 'Customer ID']]

# %% [markdown]
# 2. null values:

# %%
df = df[df['item_id'].notnull()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 584524 entries, 0 to 584523
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  float64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  float64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
#  9   sales_commission_code  447346 non-null  object
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  object
#  12  Working Date           584524 non-null  object
#  13  BI Status              584524 non-null  object
# ...

# %%
df.describe()
# Out:
#          item_id       price  qty_ordered  grand_total  discount_amount  \
# count 584524.000  584524.000   584524.000   584524.000       584524.000
# mean  565667.074    6348.748        1.296     8530.619          499.493
# std   200121.174   14949.270        3.996    61320.815         1506.943
# min   211131.000       0.000        1.000    -1594.000         -599.500
# 25%   395000.750     360.000        1.000      945.000            0.000
# 50%   568424.500     899.000        1.000     1960.400            0.000
# 75%   739106.250    4070.000        1.000     6999.000          160.500
# max   905208.000 1012625.900     1000.000 17888000.000        90300.000
#
#             Year      Month  Customer ID
# count 584524.000 584524.000   584513.000
# mean    2017.044      7.168    45790.512
# std        0.707      3.486    34414.962
# min     2016.000      1.000        1.000
# 25%     2017.000      4.000    13516.000
# 50%     2017.000      7.000    42856.000
# ...

# %%
df.describe(include='O')
# Out:
#           status  created_at                  sku increment_id  \
# count     584509      584524               584504       584524
# unique        16         789                84889       408785
# top     complete  11/25/2016  MATSAM59DB75ADB2F80    100266667
# freq      233685       15169                 3775           72
#
#           category_name_1 sales_commission_code payment_method Working Date  \
# count              584360                447346         584524       584524
# unique                 16                  7225             18          789
# top     Mobiles & Tablets                    \N            cod   11/25/2016
# freq               115710                339001         271960        15169
#
#        BI Status     MV  Customer Since      M-Y      FY
# count     584524  584524         584513   584524  584524
# unique         4    9720             26       26       3
# top          Net    999         2016-11  11-2017    FY18
# ...

# %%
df.head(2)
# Out:
#      item_id    status created_at  \
# 0 211131.000  complete   7/1/2016
# 1 211133.000  canceled   7/1/2016
#
#                                                  sku    price  qty_ordered  \
# 0                                  kreations_YI 06-L 1950.000        1.000
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...  240.000        1.000
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0     1950.000    100147443    Women's Fashion                    \N  ...
# 1      240.000    100147444  Beauty & Grooming                    \N  ...
#
#    payment_method Working Date BI Status      MV      Year  Month  \
# 0             cod     7/1/2016     #REF!   1,950  2016.000  7.000
# 1             cod     7/1/2016     Gross     240  2016.000  7.000
#
#    Customer Since     M-Y    FY Customer ID
# 0          2016-7  7-2016  FY17       1.000
# 1          2016-7  7-2016  FY17       2.000
#
# [2 rows x 21 columns]

# %%
df['item_id'].nunique()
# Out:
# 584524

# %%
df['item_id'] = df['item_id'].apply(lambda x: int(x))
# Out:
# <ipython-input-25-43475cf2b047>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['item_id'] = df['item_id'].apply(lambda x: int(x))

# %%
df.shape
# Out:
# (584524, 21)

# %%
df['item_id'].nunique()
# Out:
# 584524

# %%
df.head(2)
# Out:
#    item_id    status created_at  \
# 0   211131  complete   7/1/2016
# 1   211133  canceled   7/1/2016
#
#                                                  sku    price  qty_ordered  \
# 0                                  kreations_YI 06-L 1950.000        1.000
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...  240.000        1.000
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0     1950.000    100147443    Women's Fashion                    \N  ...
# 1      240.000    100147444  Beauty & Grooming                    \N  ...
#
#    payment_method Working Date BI Status      MV      Year  Month  \
# 0             cod     7/1/2016     #REF!   1,950  2016.000  7.000
# 1             cod     7/1/2016     Gross     240  2016.000  7.000
#
#    Customer Since     M-Y    FY Customer ID
# 0          2016-7  7-2016  FY17       1.000
# 1          2016-7  7-2016  FY17       2.000
#
# [2 rows x 21 columns]

# %%
df['item_id'].value_counts().reset_index().sort_values(by=['item_id'])
# Out:
#         item_id  count
# 0        211131      1
# 73066    211133      1
# 389683   211134      1
# 389684   211135      1
# 389685   211136      1
# ...         ...    ...
# 194845   905204      1
# 194846   905205      1
# 194847   905206      1
# 194848   905207      1
# 584523   905208      1
#
# [584524 rows x 2 columns]

# %%
df[df['qty_ordered'] == 1000]
# Out:
#         item_id    status created_at                      sku    price  \
# 239376   507556  canceled   6/8/2017       IDROID_BALRX7-Gold 8944.000
# 239377   507557  canceled   6/8/2017  IDROID_BALRX7-Jet black 8944.000
# 239381   507561  canceled   6/8/2017  IDROID_BALRX7-Jet black 8944.000
# 239382   507562  canceled   6/8/2017       IDROID_BALRX7-Gold 8944.000
# 240078   508368  complete   6/9/2017       IDROID_BALRX7-Gold 8944.000
# 240079   508369  complete   6/9/2017  IDROID_BALRX7-Jet black 8944.000
#
#         qty_ordered  grand_total increment_id    category_name_1  \
# 239376     1000.000 17888000.000    100323297  Mobiles & Tablets
# 239377     1000.000 17888000.000    100323297  Mobiles & Tablets
# 239381     1000.000 17888000.000    100323300  Mobiles & Tablets
# 239382     1000.000 17888000.000    100323300  Mobiles & Tablets
# 240078     1000.000 17888000.000    100323649  Mobiles & Tablets
# 240079     1000.000 17888000.000    100323649  Mobiles & Tablets
#
# ...

# %%
df['category_name_1'].value_counts()
# Out:
# category_name_1
# Mobiles & Tablets     115710
# Men's Fashion          92221
# Women's Fashion        59721
# Appliances             52413
# Superstore             43613
# Beauty & Grooming      41496
# Soghaat                34011
# Others                 29218
# Home & Living          26504
# Entertainment          26326
# Health & Sports        17502
# Kids & Baby            16494
# Computing              15933
# \N                      7850
# School & Education      3478
# Books                   1870
# Name: count, dtype: int64

# %%
df[df['category_name_1']=="\\N"]['sku'].value_counts()
# Out:
# sku
# emart_00-1                          1343
# Telemall_MM-DR-HB-L                  878
# test-product-00                      774
# test-product                         613
# Infinix Hot 4 Nationwide-Gold        479
#                                     ...
# clickbuscollection_nwc-29-Red          1
# clickbuscollection_nwc-29-Maroon       1
# audionic_6954217598857                 1
# clickbuscollection_nwc-33-M            1
# D Lend a Helping Hand                  1
# Name: count, Length: 295, dtype: int64

# %%
df[df['sku']=='emart_00-1']['category_name_1'].value_counts()
# Out:
# category_name_1
# \N        1343
# Others      48
# Name: count, dtype: int64

# %%
temp_df = df.groupby(by=['sku'])['category_name_1'].nunique().reset_index().sort_values(by=['category_name_1'],ascending=False)

# %%
temp_df.head(2)
# Out:
#                                          sku  category_name_1
# 79608  mt_Red-Battery-Case-for-iPhone-5-&-5s                2
# 414                  AJ-ajrak_AJA-005-Medium                2

# %%
prob_skus_ls = temp_df[temp_df['category_name_1']>1]['sku'].unique().tolist()

# %%
temp_df = df[df['sku'].isin(prob_skus_ls)]

# %%
temp_df.groupby(by=['sku','category_name_1'])['item_id'].nunique()
# Out:
# sku                                    category_name_1
# AJ-ajrak_AJA-005-Large                 Men's Fashion           2
#                                        Women's Fashion         4
# AJ-ajrak_AJA-005-Medium                Men's Fashion           1
#                                        Women's Fashion         1
# Dawlance_MD 10 + DWB 600               Appliances              2
#                                        \N                     44
# Huawei_P9Lite-Black                    Mobiles & Tablets       1
#                                        \N                     88
# Huawei_P9Lite-Gold                     Mobiles & Tablets       1
#                                        \N                     58
# JSM_JSM-001-White-Pak-Shirt-L          Men's Fashion          60
#                                        \N                      4
# JSM_JSM-001-White-Pak-Shirt-M          Men's Fashion          55
#                                        \N                      5
# ...

# %%
dummy_df = pd.DataFrame({"Name":["Ali",'Fatima'], "Age":[10,20]})

# %%
dummy_df
# Out:
#      Name  Age
# 0     Ali   10
# 1  Fatima   20

# %%
dummy_df.loc[dummy_df['Age'] == 10,'Name'] = 'Ahmed'

# %%
dummy_df
# Out:
#      Name  Age
# 0   Ahmed   10
# 1  Fatima   20

# %%
df.head(2)
# Out:
#    item_id    status created_at  \
# 0   211131  complete   7/1/2016
# 1   211133  canceled   7/1/2016
#
#                                                  sku    price  qty_ordered  \
# 0                                  kreations_YI 06-L 1950.000        1.000
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...  240.000        1.000
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0     1950.000    100147443    Women's Fashion                    \N  ...
# 1      240.000    100147444  Beauty & Grooming                    \N  ...
#
#    payment_method Working Date BI Status      MV      Year  Month  \
# 0             cod     7/1/2016     #REF!   1,950  2016.000  7.000
# 1             cod     7/1/2016     Gross     240  2016.000  7.000
#
#    Customer Since     M-Y    FY Customer ID
# 0          2016-7  7-2016  FY17       1.000
# 1          2016-7  7-2016  FY17       2.000
#
# [2 rows x 21 columns]

# %%
cache = []
for i in tqdm(prob_skus_ls):
  # fetch relevant sku #
  sample = df[df['sku']== i ]
  sample['New Category'] = sample['category_name_1']
  # find valid category other than backslash N #
  replace_val = sample[sample['category_name_1']!='\\N']['category_name_1'].values[0]
  # replace value where it make sense #
  sample.loc[sample['category_name_1']=="\\N",'New Category'] = replace_val

  # store back to df #
  cache.append(sample)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]<ipython-input-76-1574412b3d20>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['New Category'] = sample['category_name_1']
# <ipython-input-76-1574412b3d20>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['New Category'] = sample['category_name_1']
# <ipython-input-76-1574412b3d20>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
len(cache)
# Out:
# 22

# %%
cache[0]
# Out:
#         item_id          status created_at  \
# 264148   536179        complete  7/15/2017
# 266728   539014        complete  7/20/2017
# 268864   541483        complete  7/24/2017
# 270061   542799  order_refunded  7/26/2017
# 270200   542952  order_refunded  7/26/2017
# 270242   542997  order_refunded  7/26/2017
# 270770   543566  order_refunded  7/27/2017
# 270855   543669        complete  7/27/2017
# 271997   544862        received  7/28/2017
# 273354   546386        complete  7/31/2017
# 273690   546752        complete  7/31/2017
# 273913   546985  order_refunded  7/31/2017
# 277288   551437        complete   8/4/2017
# 278531   553136        received   8/7/2017
# 278587   553223        complete   8/7/2017
# 278589   553217  order_refunded   8/7/2017
#
#                                           sku   price  qty_ordered  \
# 264148  mt_Red-Battery-Case-for-iPhone-5-&-5s 665.000        1.000
# 266728  mt_Red-Battery-Case-for-iPhone-5-&-5s 665.000        1.000
# ...

# %%
prob_sku_df = pd.concat(cache, ignore_index=False)

# %%
prob_sku_df.shape
# Out:
# (3470, 22)

# %%
df.shape
# Out:
# (584524, 21)

# %%
prob_sku_df['category_name_1'] = prob_sku_df['New Category']
prob_sku_df = prob_sku_df.drop(columns=['New Category'])

# %%
prob_sku_df.shape
# Out:
# (3470, 21)

# %%
df = df[~df['sku'].isin(prob_skus_ls)]

# %%
final_df = pd.concat([df, prob_sku_df], ignore_index=False)

# %%
final_df.groupby(by=['sku'])['category_name_1'].nunique().sort_values(ascending=False)
# Out:
# sku
# AJ-ajrak_AJA-005-Medium    2
# AJ-ajrak_AJA-005-Large     2
#  Huawei Mate 8             1
# SMSM_2703076               1
# SMSM_2703187               1
#                           ..
# MEFQMO5A963699761E6        0
# MEFQMO5A963699BA878        0
# MATHAP5A698AF771FCD        0
# KABASA5ABC763F62E76        0
# COMWD5AA8FF5851E73         0
# Name: category_name_1, Length: 84889, dtype: int64

# %%
master_df = df[['sku','category_name_1']]

# %%
master_df.drop_duplicates().sort_values(by=['sku'])
# Out:
#                                                 sku    category_name_1
# 19328                                 Huawei Mate 8  Mobiles & Tablets
# 122484   MHS_Kiss Bed Set-Bed Sheet - [Size] Double      Home & Living
# 289174                         jjp_15000006-100-NIL  Beauty & Grooming
# 257122                20-herbal_Face Cleaner Lotion  Beauty & Grooming
# 47174                            20-herbal_Hair Oil    Health & Sports
# ...                                             ...                ...
# 16267                                  zuni16_315-A    Women's Fashion
# 16837                                  zuni16_317-A    Women's Fashion
# 18223                                  zuni16_319-A    Women's Fashion
# 14846                                           NaN                 \N
# 325391                                          NaN      Entertainment
#
# [84873 rows x 2 columns]

# %%
df.shape
# Out:
# (584524, 21)

# %%
sample['New Category'].value_counts()
# Out:
# New Category
# Mobiles & Tablets    16
# Name: count, dtype: int64

# %%
re
